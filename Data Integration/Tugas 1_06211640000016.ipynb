# %% [markdown]
# # Tugas 1

# %% [markdown]
# ## Data Integration

# %%
import pandas as pd
data1=pd.read_csv('data tugas 1.csv',sep=';')
data2=pd.read_csv('data tugas 1 tambahan.csv',sep=';')
data_complete=pd.merge(data1, data2, on ='Provinsi')
data_complete
# Out:
#                      Provinsi            Stasiun BMKG  \
# 0                        Aceh    Sultan Iskandar Muda
# 1              Sumatera Utara              Kualanamu1
# 2              Sumatera Barat                Sicincin
# 3                        Riau  Sultan Syarif Kasim II
# 4                       Jambi           Sultan Thaha2
# 5            Sumatera Selatan                  Kenten
# 6                    Bengkulu              Pulau Baai
# 7                     Lampung          Radin Inten II
# 8   Kepulauan Bangka Belitung             Depati Amir
# 9              Kepulauan Riau                  Kijang
# 10                DKI Jakarta              Kemayoran3
# 11                 Jawa Barat                 Bandung
# 12                Jawa Tengah                Semarang
# 13              DI Yogyakarta              Yogyakarta
# 14                 Jawa Timur                  Juanda
# 15                     Banten                  Serang
# ...
